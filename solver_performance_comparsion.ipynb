# %%
# Files from repository
from experiments.experiment_scripts.appendix_pbo_solver_performance_comparsion import *

# %%
results = compare_miqp_pbo(n_values=[20,50,100,200,500,1000,2000])

# %%
results = load_pbo_results("results.json")
results
# Out:
# {'n_values': [20, 50, 100, 200, 500, 1000, 2000],
#  'gurobi_mip_times': [0.0424494743347168,
#   0.19449901580810547,
#   0.7189896106719971,
#   5.096338748931885,
#   11.3931245803833,
#   64.0829701423645,
#   877.2616288661957],
#  'gurobi_pbo_times': [0.08701586723327637,
#   0.4685513973236084,
#   2.572205066680908,
#   619.9256553649902,
#   10566.146807193756],
#  'scip_pbo_times': [0.24912166595458984, 8.786630868911743, 586.3740537166595]}

# %%
plot_comparison(results)
